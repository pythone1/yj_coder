# %%
import pandas as pd
import os,glob
BZ = '必填项检查'

# %%
# pth = r'E:\全省养殖池溏上图入库普查\合规性检查'
# os.chdir(pth)
# xls_file = '汇总'
# if os.path.isdir(xls_file):
#     files = glob.glob(f"{xls_file}\\*.xlsx")
#     df_list = []
#     for f in files:
#         print(f"read {f}")
#         df_list.append(pd.read_excel(f, dtype=str))  #, skiprows=1
#     ctxx = pd.concat(df_list,ignore_index=True)
# else:
xls_file =r'E:\PY\jupyter\常州市.xlsx'
ctxx = pd.read_excel(xls_file, dtype=str)
ctxx[BZ]=''

# %%
df_yz = ctxx[ctxx['养殖状态'].str.contains('养殖')]

# %%
df=df_yz

# %%
# 检查手机号码和联系方式为11位数字
for col in ['手机号码', '联系方式']:
    idx = df[(df[col] != '') & ~df[col].str.match(r'^\d{11}$')].index
    df.loc[idx, BZ] += f"{col}非11位手机号码，"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 3
#       1 # 检查手机号码和联系方式为11位数字
#       2 for col in ['手机号码', '联系方式']:
# ----> 3     idx = df[(df[col] != '') & ~df[col].str.match(r'^\d{11}$')].index
#       4     df.loc[idx, BZ] += f"{col}非11位手机号码，"
#
# File D:\APP\anaconda\Lib\site-packages\pandas\core\generic.py:1461, in NDFrame.__invert__(self)
#    1457 if not self.size:
#    1458     # inv fails with 0 len
#    1459     return self.copy(deep=False)
# -> 1461 new_data = self._mgr.apply(operator.invert)
#    1462 return self._constructor(new_data).__finalize__(self, method="__invert__")
#
# File D:\APP\anaconda\Lib\site-packages\pandas\core\internals\managers.py:350, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     347             kwargs[k] = obj[b.mgr_locs.indexer]
#     349 if callable(f):
# --> 350     applied = b.apply(f, **kwargs)
# ...

# %%
df.to_excel(r'E:\PY\jupyter\test.xlsx')
